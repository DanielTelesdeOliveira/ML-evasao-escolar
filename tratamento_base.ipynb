# %%
import pandas as pd
import gdown
from dotenv import load_dotenv
import os

# %%
load_dotenv() #Carregando variáveis do ambiente
# Out:
# True

# %%
id_arquivo = os.getenv("id_arquivo")
url = os.getenv("url")
url_arquivo = f'{url}{id_arquivo}'

# %%
#Nome do arquivo CSV
output = 'base_inep.csv'

# O gdown consegue "pular" o aviso de vírus de arquivos grandes
#Download do CSV filtrado com os dados de SP
gdown.download(url_arquivo, output, quiet=False)

df = pd.read_csv(output, sep=',', encoding='utf-8')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1YPjM9cEc3bgvRn3d7yh2JirZCvam0RC_
# From (redirected): https://drive.google.com/uc?id=1YPjM9cEc3bgvRn3d7yh2JirZCvam0RC_&confirm=t&uuid=8f7fb0c1-e5c2-4110-94c9-306e192a6321
# To: c:\Users\User\OneDrive\Documentos\Faculdade\TCC\EvasaoEscolar\base_inep.csv
# 100%|██████████| 208M/208M [00:06<00:00, 33.5MB/s]

# %%
df
# Out:
#         Unnamed: 0  ID_SAEB  ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_AREA  \
# 0          1126865     2023          3     35       6325437        2
# 1          1126866     2023          3     35       6325437        2
# 2          1126867     2023          3     35       6325437        2
# 3          1126868     2023          3     35       6325437        2
# 4          1126869     2023          3     35       6325437        2
# ...            ...      ...        ...    ...           ...      ...
# 542063     1668928     2023          3     35       6326081        2
# 542064     1668929     2023          3     35       6326081        2
# 542065     1668930     2023          3     35       6326081        2
# 542066     1668931     2023          3     35       6326081        2
# 542067     1668932     2023          3     35       6326081        2
#
#         ID_ESCOLA  IN_PUBLICA  ID_LOCALIZACAO  ID_TURMA  ...  TX_RESP_Q23b  \
# 0        61401231           1               1   1519896  ...             .
# 1        61401231           1               1   1519896  ...             C
# 2        61401231           1               1   1519896  ...             B
# 3        61401231           1               1   1519896  ...             C
# 4        61401231           1               1   1519896  ...             C
# ...           ...         ...             ...       ...  ...           ...
# 542063   61433775           1               1   1724672  ...             C
# 542064   61433775           1               1   1724672  ...             B
# 542065   61433775           1               1   1724672  ...             A
# 542066   61433775           1               1   1724672  ...             C
# 542067   61433775           1               1   1724672  ...             B
#
#         TX_RESP_Q23c  TX_RESP_Q23d  TX_RESP_Q23e  TX_RESP_Q23f  TX_RESP_Q23g  \
# 0                  .             .             .             .             .
# 1                  A             A             B             A             C
# 2                  B             B             B             C             B
# 3                  A             B             A             A             B
# 4                  B             A             B             C             B
# ...              ...           ...           ...           ...           ...
# 542063             B             B             B             C             A
# 542064             C             C             C             B             B
# 542065             C             B             A             C             A
# 542066             D             B             A             B             D
# 542067             B             B             B             C             C
#
#         TX_RESP_Q23h  TX_RESP_Q23i  TX_RESP_Q24  TX_RESP_Q25
# 0                  .             .            .            .
# 1                  A             A            C            A
# 2                  A             A            D            A
# 3                  .             A            B            A
# 4                  A             A            C            A
# ...              ...           ...          ...          ...
# 542063             B             B            B            A
# 542064             B             B            C            A
# 542065             A             A            C            A
# 542066             A             A            D            A
# 542067             B             B            C            B
#
# [542068 rows x 118 columns]
